# %% [markdown]
# <a href="https://colab.research.google.com/github/pallavmarch/Psychologytoday-therapist-analysis/blob/main/States_loop_Dementia_suicidal_analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Start ⭐

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import re
from google.colab import files
import warnings
warnings.filterwarnings("ignore")

# !pip install xlsxwriter

states = ["texas", "california", "florida", "new-york"]

# %% [markdown]
# # Function & Groups ➿

# %% [markdown]
# ## Groups

# %% [markdown]
# ### Insurance ⚕

# %%
############################### Insurance  ###############################

insurance_groups = {
    "Aetna": ["aetna", "aetna cvshealth", "aetna eap",
              "allied benefit systems- aetna", "health scope- aetna", "trustmark health benefits-aetn",
              "webtpa - aetna"],
    "Blue Cross Blue Shield (BCBS)": ["bluecross and blueshield", "blue cross", "blue shield", "horizon blue cross and blue shield",
                                       "blue cross blue shield of ma", "bcbs ppo", "bcbs ma", "bcbs blue advantage hmo", "bcbs healthselect hmo",
                                      "Empire Blue Cross Blue Shield","empire blue cross blue shield", "independence blue cross",
                                      "excellus bluecross blueshield", "blue cross uship only", "blue care network", "blue shield of ca - medi-cal",
                                      "independence blue cross penn", "highmark", "highmark bcbs medicaid of wny",
                                      "highmark bcbs of western new york", "highmark blueshield of ne",
                                      "bcbs of ma in ny", "blue cross blue shield health plus", "blue cross blue shield of mass",
                                      "blueshield of northeastern new york", "some bcbs insurances"
                              ],
    "Cigna & Evernorth": ["cigna and evernorth", "cigna evernorth & eap", "eap:cigna", "cigna eap"],
    "UnitedHealthcare & Optum": ["unitedhealthcare uhc", "ubh", "optum", "united health/optum", "united healthcare optum & eap",
                                 "uhc medicare advantage", "uhc student resources",
                                  "united behavioral systems", "uhc allsavers", "uhc oxford", "uhc student resources", "united all savers",
                                 "united behavioral health", "united bind", "united ghea/shared services",
                                 "united health - allsavers", "united health - surest", "united health care",
                                 "united healthcare (optum)", "united healthcare (tx)", "united healthcare global",
                                 "united healthcare golden rule", "united healthcare shared servi",
                                 "united healthscope benefits", "united oxford (tx)", "united student resources (tx)",
                                 "united umr"],
    "Humana": ["humana", "humana eap", "humana tricare", "humana military", "tricare military-humana military"],
    "Oscar Health": ["oscar health"],
    "United Medical Resources": ["united medical resources (umr)", "umr - mount sinai employees", "umr top tier plan mt. sinai"],
    "Medicaid": ["aetna medicaid", "uhc medicaid", "medicaid", "superior medicaid", "chip/chip plus",
                 "bcbs medicaid, sendero", "cenpatico/superior/imhs/star health", "community first",
                 "driscoll health plan", "sendero health plans", "humana - dual", "united health/optum - medicaid",
                 "medi-cal", "only accept medi-cal if also medi-care", "medicaid managed care plans", "blue choice option (medicaid)",
                  "cdphp medicaid", "mvp medicaid", "optum medicaid"],
    "Magellan": ["magellan", "magellan behavioral health"],
    "Oxford": ["oxford"],
    "Amerigroup": ["amerigroup", "amerigroup mediblue hmo and ppo"],
    "Medicare": ["medicare", "medicare (railroad)", "aetna medicare", "aetna - medicare", "uhc medicare", "humana medicare", "anthem medicare advantage",
                 "humana - medicare", "united - medicare advantage", "scan medicare advantage", "aetna medicare advantage",
                 "bcbs medicare advantage hmo", "bcbs medicare advantage ppo", "s&w medicare advantage", "united health/optum - medicare",
                 "medicare with a supplement", "- medicare in network -", "humana - medicare", "optum medicare",
                  "united healthcare medicare", "united healthcare medicare adv", "cdphp medicare", "mvp medicare",
                 "united umr top tier (mt sinai)"],
    "EAP Providers": ["carebridge eap", "continuum eap", "alliance work partners (eap)", "united healthcare optum & eap",
                      "lyra eap", "anthem eap - bank of america", "eap:united health/optum", "eap: united health/optum", "eap:cigna",
                      "modern health eap", "curalinc eap", "empathia eap", "claremont eap",
                      "employee assistance programs", "eap:unitedhealthcare/optum", "eaps: curalink, lifeworks, cascade",
                      "eaps: aetna resources for living, mhn, beacon eap", "eaps: employee resource systems, r3 continuum",
                      "eaps: magellan, morneau shepell, espyr, esi, optum", "eaps: workplace options, amerigroup, molina, unum",
                      "empathia", "esi employee assistance group", "lexington health eap", "mines eap",
                      "wellspring eap", "workplace options", "lyra", "lyra health"],
    "Military & Government": ["tricare", "tricare east out of network", "triwest", "champva", "us family health plan",
                              "military onesource","government employees health association (geha)",
                              "va community care network (ccn)", "risk management for loma linda university staff, students"],
    "Networks & Multiplan": ["multiplan", "multiplan private healthcare systems (phcs)", "multi plan phcs"],
    "First Health Network": ["first health", "first health network", "preferred administrators"],
    "Private Payment & Out of Network": ["out of network", "private payment", "i am an out of network provide", "private pay", "self-pay",
                                         "kaiser (out-of-network)", "provide superbill for insurance reimbursement",
                                          "provide superbill for out of network reimbursement", "any/out-of-network insurance",
                                          "superbills available", "will provide superbill for insurance reimbursement",
                                          "ppo", "ppo plans", "ppo out of network", "ppo/ superbill", "other insurances may be accepted.",
                                        "will submit all in/out of network billing for you", "will call for you to confirm/check your coverage",
                                        "often negotiate with insurance to cover services","no charge for initial phone consult"],
    "Anthem":["anthem","anthem blue cross ppo",  "anthem blue cross blue shield", "anthem eap bank of america", "anthem healthkeepers", "anthem bcbs of ny",
        "anthem blue cross/blue shield", "anthem eap", "anthem eap-bank of america tn"],
    "Carelon Behavioral Health": ["carelon behavioral health", "carelon health ipa of california (chipa)", "carelon medicare advantage",
                                  "carelon - (oon)"],
    "Coventry":["coventry"],
    "Superior Healthplan": ["superior healthplan"],
    "Ambetter": ["ambetter"],
    "Compsych": ["compsych"],
    "Wellpoint": ["wellpoint"],
    "Sutter": ["sutter"],
    "Managed Health Network (MHN)": ["managed health network (mhn)"],
    "Health Net": ["health net"],
    "MHNet Behavioral Health": ["mhnet behavioral health"],
    "Florida Blue": ["florida blue"],
    "Lucet": ["lucet"],
    "New Directions": ["new directions"],
    "AvMed": ["avmed"],
    "WellCare": ["wellcare"],
    "Behavioral Health Systems": ["behavioral health systems", "bhs"],
    "Kaiser": [
        "kaiser (southern ca)", "kaiser socal", "kaiser norcal", "kaiser northern ca",
        "kaiser permanente (southern ca)"
    ],
    "Not Found": ["not found"]
}

# %% [markdown]
# ### Title

# %%
############################### Title  ###############################

title_groups = {
    "Licensed Professional Counselors (LPC)": [
        "licensed professional counselor", "licensed professional counselor associate",
        "lpc intern", "lpc-associate", "lpc associate"
    ],
    "Clinical Social Workers (LCSW)": [
        "clinical social work/therapist", "master social worker"
    ],
    "Psychologists (PhD/PsyD)": [
        "psychologist", "psychological associate"
    ],
    "Marriage & Family Therapists (LMFT)": [
        "marriage & family therapist", "marriage & family therapist associate"
    ],
    "Nurse Practitioners & Medical Professionals": [
        "pmhnp(he", "fnp"
    ],
    "Pre-Licensed & Interns": [
        "pre-licensed professional", "lpc intern"
    ],
    "Counselor": [
        "counselor", "counselor intern", "counselor associate"
    ],
    "Other": []
}

# %% [markdown]
# ### Credential

# %%
############################### Credential  ###############################

credential_groups = {

        "Doctoral Degrees": [
            "PhD", "PsyD", "EdD", "DSW", "DBH", "Pharm D", "Psy", "MP"
        ],
        "Master’s Degrees": [
            "MA", "MS", "MSW", "MSSW", "MEd", "MBA", "MHR", "MPH", "MABC", "MS Ed", "MSCP", "MMFT", "MC", "MDiv", "MTS", "MPA"
        ],
        "Bachelor’s Degrees": [
            "BA", "BS", "BS Ed", "BAS"
        ],
        "Specialized Academic": [
            "MLS", "MS SLP", "MSN", "BCS", "CSC"
        ],

        "Social Work Licenses": [
            "LCSW", "LCSW-S", "LMSW", "LMSW-IP", "LSW", "LBSW-IP"
        ],
        "Professional Counselors": [
            "LPC", "LPC-S", "LPC-A", "LPCA", "LPC/S"
        ],
        "Marriage & Family Therapy": [
            "LMFT", "LMFT-A", "LMFT-S"
        ],
        "Psychologists": [
            "LP", "LPA", "LCP"
        ],
        "Chemical Dependency": [
            "LCDC", "LCDC-I", "LCDC-i", "ADC"
        ],
        "Other Licenses": [
            "RN", "FNP", "FNP-C", "PMHNP", "LMT", "LSSP"
        ],

        "Counseling & Therapy Certifications": [
            "NCC", "CRC", "BCD", "BCPC", "BCN", "CAMS-II", "RPT", "RPT-S",
            "CCTP", "CCTSI", "CCTS-I", "EMDR", "EMDRIA", "EMDR-T", "EMDR-t",
            "TF-CBT", "CART", "CSC", "ASDCS", "CPT", "CAATS", "CAIMHP", "CIMHP", "PMH-C", "SEP"
        ],
        "Substance Abuse / Addiction Certifications": [
            "DOT-SAP", "SAP", "MAC", "CAC"
        ],
        "Leadership / Coaching Certifications": [
            "BCC", "CEO", "IECA"
        ],
        "Spiritual / Alternative Certifications": [
            "CCH", "CLYL", "IP"
        ],
        "Other Certifications": [
            "QME", "CGE", "CCSRRS", "CDP", "LSW", "CHt", "AAMFT", "Author"
        ],
}

# %% [markdown]
# ### Expertise

# %%
############################### Expertise  ###############################

expertise_groups = {
    "Anxiety, Mood, and Emotional Disorders": [
        "anxiety", "stress", "depression", "mood disorders",
        "obsessive-compulsive (ocd)", "impulse control disorders",
        "bipolar disorder", "personality disorders", "borderline personality (bpd)",
        "antisocial personality", "narcissistic personality (npd)", "psychosis",
        "emotional disturbance"
    ],
    "Trauma, PTSD, and Abuse": [
        "trauma and ptsd", "childhood trauma", "adjustment issues", "sexual abuse",
        "domestic violence", "domestic abuse", "military sexual trauma", "spiritual abuse/trauma",
        "religious trauma and abuse", "death and dying", "anticipatory grief", "traumatic bereavement & caregiving issue",
        "ptsd, geriatrics counseling", "veterans", "veteran transitions", "first responders"
    ],
    "Relationship & Family Issues": [
        "marital and premarital", "couples counseling", "peer relationships",
        "relationship issues", "divorce", "divorce adjustment, parental alienation",
        "parenting", "parent/child alienation and re-unification", "infidelity",
        "affair recovery", "boundaries, communication, life transitions"
    ],
    "LGBTQ+ & Gender Identity Issues": [
        "lgbtq+", "lesbian", "bisexual", "transgender", "lgbtqi",
        "gender identity", "heterosexual issues", "open relationships non-monogamy",
        "sex-positive, kink allied", "kink aware"
    ],
    "Addiction & Substance Use": [
        "addiction", "alcohol use", "substance use", "substance misuse", "gambling",
        "internet addiction", "video game addiction", "sex addiction",
        "spouses of sex addicts", "chronic impulsivity", "chronic relapse",
        "dual diagnosis", "medical detox"
    ],
    "Neurodevelopmental & Learning Disabilities": [
        "adhd", "autism", "intellectual disability", "asperger's syndrome",
        "developmental disorders", "education and learning disabilities", "testing and evaluation"
    ],
    "Dementia & Aging-Related Issues": [
        "dementia", "loved ones of dementia patients", "cognitive rehabilitation therapy",
        "neuropsychological assessment", "neuropsychological testing to rule out dementia",
        "brain injuries, dementia, epilepsy", "stroke", "functional neurological disorder (fnd)",
        "transition to aging and loss of independence", "eldercare/caregiver fatigue, retirement, aging",
        "aging and caregiving preparation", "preparation for retirement"
    ],
    "Chronic Illness & Pain Management": [
        "chronic illness", "chronic pain", "illness and disability", "autoimmune disease",
        "spinal cord", "complex/multiple medical conditions", "terminal/life-limiting illness", "terminal illness"
    ],
    "Workplace & Career Issues": [
        "career counseling", "occupational issues", "relationship at work and business",
        "mental health for business professionals", "workplace stress", "supervision, professional consultation"
    ],
    "Family & Caregiver Support": [
        "caregivers", "caregiver stress", "caregiver burnout", "caregiver therapy",
        "caretakers for dementia", "caregiver responsibilities", "providing support to frontline health care workers"
    ],
    "Therapy Specializations & Techniques": [
        "cbt", "emdr", "emdr trained", "emdr therapy basic training", "hypnotherapy",
        "trauma focused / cbt certified", "christian counseling", "spirituality",
        "pre-surgical evaluations (e.g., bariatric, etc.)", "psychological & cognitive testing"
    ],
    "Child & Adolescent Issues": [
        "child", "infant mental health, play therapy", "childhood trauma", "adoption",
        "school issues", "school and behavior problems", "teen violence"
    ],
    "Coping Skills & Resilience": [
        "coping skills", "emotional regulation", "stress management",
        "mindfulness", "self-care", "adaptive coping strategies"
    ],
    "Family Conflict & Relationships": [
        "family conflict", "family dynamics", "blended families",
        "communication issues", "parent-child conflict", "estrangement"
    ],
    "Geriatric & Senior Mental Health": [
        "geriatric and seniors", "aging issues", "end-of-life counseling",
        "adjusting to retirement", "elderly support", "memory loss support"
    ],
    "Women's Issues": [
        "women's issues", "woman's issues","pregnancy, prenatal, postpartum", "menopause support",
        "gender-based challenges", "maternal mental health"
    ],
    "Behavioral Issues & Impulse Control": [
        "behavioral issues", "anger management", "impulse control",
        "oppositional defiant disorder (ODD)", "oppositional defiance (odd)", "suicide prevention",
        "conduct disorder", "aggression management", "self esteem", "self-harming", "suicidal ideation", "stress",
    ],
    "Cancer & Chronic Illness Support": [
        "cancer", "cancer support", "chronic illness", "palliative care",
        "life-limiting illness", "terminal illness counseling"
    ],
    "Thinking Disorders & Cognitive Challenges": [
        "thinking disorders", "cognitive impairments", "delusional disorders",
        "thought disorder", "executive dysfunction"
    ],
    "Body Positivity & Self-Esteem": [
        "body positivity", "self-esteem", "body image", "self-acceptance", "eating disorders",
        "weight stigma", "self-worth", "weight loss", "obesity"
    ],
    "Substance Use & Drug Abuse": [
        "drug abuse", "substance use", "addiction recovery", "relapse prevention",
        "opioid use disorder", "alcoholism", "harm reduction strategies"
    ],
    "Men's Issues": [
        "men's issues", "masculinity and mental health", "fatherhood",
        "male depression", "emotional expression challenges"
    ],
    "Other": []
}

# %% [markdown]
# ### Top Specialties

# %%
############################### Specialties  ###############################

top_specialties_groups = {
    "Anxiety, Mood, and Emotional Disorders": [
        "depression", "anxiety", "mood disorders", "bipolar disorder",
        "emotional disturbance", "thinking disorders", "psychosis",
        "borderline personality (bpd)", "stress",
        "anger management", "obsessive-compulsive (ocd)",
        "self esteem", "sleep or insomnia", "suicidal ideation"

    ],
    "Trauma, PTSD, and Abuse": [
        "trauma and ptsd", "sexual abuse", "domestic violence",
        "leaving religion/religious trauma", "psychological / forensic evaluations for court"
    ],
    "Relationship & Family Issues": [
        "relationship issues", "family conflict", "marital and premarital",
        "infidelity", "family of origin issues", "divorce",
        "open relationships non-monogamy", "codependency", "coping skills"
    ],
    "LGBTQ+ & Gender Identity Issues": [
        "lgbtq+", "transgender", "multicultural + intergenerational issues"
    ],
    "Addiction & Substance Use": [
        "addiction", "substance use", "sexual addiction", "dual diagnosis",
         "drug abuse", "eating disorders"
    ],
    "Child & Adolescent Issues": [
        "child", "child or adolescent", "parenting", "school issues",
        "education and learning disabilities", "oppositional defiance (odd)",
        "teen violence", "peer relationships"
    ],
    "Neurodevelopmental & Learning Disabilities": [
        "adhd", "autism", "adhd / autism / diagnostic evaluations",
        "testing and evaluation", "developmental disorders",
        "asperger's syndrome", "intellectual disability",
        "neuropsychological testing", "neuropsychological testing and evaluation",
        "neuropsychological testing including adhd testing", "neuropsychology"
    ],
    "Dementia & Aging-Related Issues": [
        "dementia", "geriatric and seniors", "aging", "traumatic brain injury (tbi)",
                "dementia/alzheimer's disease", "alzheimer's disease", "memory / dementia testing /fit-for-duty evaluation"
    ],
    "Chronic Illness & Pain Management": [
        "chronic illness", "chronic pain", "obesity",
        "pain management", "dealing with diagnosis with illness especially ca"
    ],
    "Career & Life Coaching": [
        "career counseling", "life transitions", "life coaching"
    ],

    "Veterans & Military Issues": [
        "veterans", "military issues", "deployment", "military family transition"
    ],
    "Mental Health/Behavioral Issues": [
        "Anger Management", "Behavioral Issues", "Coping Skills",
        "Codependency", "Self-Esteem", "Sleep or Insomnia"
    ],
    "Grief & Caregiver Support": [
        "grief", "caregivers", "pet loss", "pregnancy, prenatal, postpartum", "infertility"
    ],
    "Cognitive & Diagnostic Evaluation": [
        "differential diagnosis", "psychological / forensic evaluations for court",
        "medical issues", "medication management"
    ],
    "Men’s & Women’s Issues": [
        "men's issues", "women's issues"
    ],
    "Life Adjustments & Identity": [
        "adoption", "acquired disability (e.g., stroke, amputation)"
    ],
    "Other": []
}

# %% [markdown]
# ### Therapy Types

# %%
############################### Therapy Types  ###############################

therapy_types_groups = {
    "Cognitive & Behavioral Therapies": [
        "cognitive behavioral (cbt)", "dialectical behavior (dbt)", "acceptance and commitment (act)",
        "rational emotive behavior (rebt)", "cognitive processing therapy (cpt)",
        "cognitive processing (cpt)", "cognitive rehabilitation", "exposure response prevention (erp)",
        "schema therapy", "cognitive processing therapy (cpt) for ptsd"
    ],
    "Emotionally & Relational Focused Therapies": [
        "emotionally focused", "emotionally focused couple therapy",
        "emotionally focused therapy (eft)", "attachment-based", "gottman method", "imago",
        "relational", "pact(psychobiological approach to couples therapy)",
        "psychobiological approach couple therapy","aedp"
    ],
    "Trauma & Recovery Therapies": [
        "trauma focused", "emdr", "brainspotting", "prolonged exposure therapy",
        "equine therapy, emdr", "accelerated resolution therapy (art)", "internal family systems (ifs)",
        "sandplay", "dreamwork, shamanic, depth psychology", "complicated grief therapy (cgt)"
    ],
    "Family & Couples Therapies": [
        "family / marital", "family systems", "structural family therapy",
        "strategic family therapy", "bowen family systems",
        "couples and family therapy, in-home hoarding","parent-child interaction (pcit)"
    ],
    "Expressive & Experiential Therapies": [
        "art therapy", "music therapy", "dance movement therapy", "expressive arts",
        "play therapy", "clay therapy", "sand tray"
    ],
    "Faith-Based & Spiritual Therapies": [
        "christian counseling", "faith-based", "faith based", "faith based therapy - upon request",
        "forgiveness and compassion therapy", "logotherapy", "spirituality", "liberation psychology",
        "decolonial anti-oppressive therapy"
    ],
    "Psychoanalytic & Psychodynamic Therapies": [
        "psychoanalytic", "psychodynamic", "jungian", "transactional therapy"
    ],
    "Therapeutic Approaches": [
        "12 step model", "acceptance commitment therapy", "applied behavioral analysis (aba)",
        "crisis stabilization", "eclectic", "eft aka tapping", "emdr, abuse, trauma, grief, women's issues",
        "feminist", "forensic psychology", "gestalt", "grief therapy", "grief/bereavement",
        "intervention", "motivational interviewing", "narrative", "person-centered",
        "reality therapy, trained in emdr", "reminiscence", "sex therapy", "somatic", "talk therapy",
        "transpersonal","interpersonal"
    ],
    "Alternative & Integrative Therapies": [
        "hypnotherapy", "neurofeedback", "biofeedback", "energy psychology", "reiki",
        "animal assisted interventions", "animal assisted therapy", "mind/body integration",
        "breathing for stress reduction", "emotional transformation therapy", "equine-assisted psychotherapy"
    ],
    "Supervision & Coaching": [
        "clinical supervision and licensed supervisors", "coaching", "life coaching",
        "therapeutic parenting skills, parent coaching"
    ],
    "Multicultural & Sensitivity-Based Therapies": [
        "multicultural", "culturally sensitive", "evaluaciones de inmigracion", "immigration evaluations"
    ],
    "Medical & Neuropsychological Evaluations": [
        "psychological testing and evaluation", "psychological evaluation",
        "comprehensive diagnostic evaluation services", "neuro-linguistic (nlp)",
        "adhd testing", "neuropsychological evaluations", "medication management",
        "vocational interest testing", "comprehensive behavioral intervention for tics"
    ],
    "Psychedelic & Ketamine-Assisted Therapies": [
        "ketamine-assisted", "ketamine assisted psychotherapy", "psychedelic therapy integration",
        "mycs neurological integrative therapy"
    ],
    "Other": []
}

# %% [markdown]
# ### Certificate

# %%
############################### Certificate  ###############################

certificate_groups = {
    "Marriage & Family Therapy (MFT)": [
        "aamft", "aamftmft supervisor", "american assoc. for marriage and family therapists",
        "ca assoc. for marriage and family therapists", "camft"
    ],
    "EMDR & Trauma Therapy": [
        "emdria", "emdr association", "emdr therapy basic training", "emdria international association",
        "emdr and brainspotting trained", "brainspotting", "certified clinical trauma professional",
        "postpartum support internationalperinatal mental health", "trauma focused cognitive behavior therapy"
    ],
    "Gottman & Couples Counseling": [
        "the gottman institute: gottman method couples therapy level &", "gottman level trained therapist",
        "prepare-enrich curriculum facilitator", "relational life therapy certified couples therapist"
    ],
    "Christian & Faith-Based Counseling": [
        "american association of christian counselors", "christian association for psychological studies",
        "church of the nazareneordained minister", "evangelical lutheran church in americaretired clergy"
    ],
    "Immigration & Mediation Certifications": [
        "mediators of texas", "immigration evaluation certification", "alternative dispute resolution",
        "foothill collegecertificate as a mediator"
    ],
    "National & State Licensing Boards": [
        "state of texaslcdc", "texaslpc", "tx state board of examiners of professnl counselor",
        "texas counseling association#", "state board of health", "tx state board of social worker examinerslcsw-s",
        "texas state board of examiners of psychologists", "texas department of state health serviceslcdc",
        "texas education agencytx certified school counselor", "texas state board of examiners of lpcsapproved state supervisor",
        "california board of psychology", "florida board of psychology", "california department of industrial relationsqualified medical examiner"
    ],
    "Social Work & Mental Health Associations": [
        "nasw", "nasw association", "american board of clinical social work",
        "national board for certified counselors", "national board for certified counselors inc.",
        "national board of certified counselors", "national certified counselor-nbcc",
        "national council of certified dementia practitionerscdp", "professional counselor - supervisor",
        "california society for clinical social work", "board of behavioral sciences"
    ],
    "University & Higher Education Credentials": [
        "southern methodist universitym.s. in counseling", "loyola university of chicagomaster of arts in psychology",
        "capella universitygeriatric psychology", "argosy university dallasdoctorate in clinical psychology",
        "walden universityphd. clinical psychology", "prairie view a&m universitycertified school counselor",
        "university of houston graduate college social workm.s.w.", "universidad europea miguel de cervantesneuropsychology-dementia",
        "attendedregis college post-master's certificate graduated", "east texas baptist univ.",
        "university of california at irvineb.a. psych and social behavior", "usc keck school of medicinemph"
    ],
    "Play Therapy & Child Counseling": [
        "hcc-texas association for play therapy", "association for play therapy united states"
    ],
    "General Professional Associations": [
        "american assoc. for marriage and family therapists", "american counseling association",
        "american psychotherapy association", "nasw association", "national board for certified counselors",
        "national board of certified counselors", "national certified counselor-nbcc",
        "national council of certified dementia practitioners (cdp)", "national register of health service psychologists",
        "professional counselor - supervisor", "state board of health", "texas counseling association",
        "texas state board of examiners of lpcs approved state supervisor",
        "texas state board of examiners of psychologists", "tx state board of social worker examiners lcsw-s",
        "american psychological association", "american board of professional neuropsychology"
    ],
    "Yoga, Somatic & Holistic Therapies": [
        "registered yoga teacher - yoga alliance", "somatic experiencing institute",
        "institute for aerobics researchphysical fitness specialist"
    ],
    "Psychiatric Tools & Credentialing": [
        "cpr & aed", "asha certificate of clinical competence", "bciae", "ccsas", "psypact", "laban",
        "biofeedback certificaton international alliance", "biofeedback certification international alliance"
    ],
    "Dementia & Geriatric Specializations": [
        "universidad europea miguel de cervantesneuropsychology-dementia",
        "national council of certified dementia practitionerscdp",
        "nccdp- certified dementia care practitioner"
    ],
    "Health & Case Management Certifications": [
        "national academy of certified care managers (naccm)", "commission for case management certification",
        "the commission for case manager certification", "hospice and palliative credentialing center (hpcc)"
    ],
    "Supervision & Teaching Credentials": [
        "california association: marriage & family therapy certified supervisor",
        "board of behavioral scienceslmft supervisor", "texas state board of examiners of lpcs approved state supervisor"
    ],
    "Neuropsychology & Psychological Testing": [
        "apa, aamha, ins, nandiplomate clinical neuropsych",
        "absi advanced certification in psychological testing and assessment"
    ],

        "Trauma & Crisis Counseling": [
            "certified clinical trauma professional (CCTP)",
            "certified clinical trauma professional - level II - evergreen certifications",
            "certified trauma professional (CTP)",
            "trauma focused cognitive behavioral therapy (TF-CBT)"
        ],
        "Addiction & Mental Health Counseling": [
            "certified addiction professional",
            "clinical anxiety treatment professional",
            "licensed mental health counselor",
            "licensed mental health counselor MH",
            "master certified accelerated resolution therapist",
            "board certified sex therapist",
            "brief strategic family therapy (evidence-based) national trainer"
        ],
        "Play Therapy & Family Therapy": [
            "internal family systems and psychedelic therapy",
            "eagala",
            "certified state of Florida clinical supervisor for registered clinical social worker interns (SW)"
        ],
        "EMDR & Cognitive Behavioral Therapy (CBT)": [
            "emdr",
            "emdr international association certified emdr therapist",
            "emdria basic training",
            "emdria certified",
            "evergreen certifications (Certified Clinical Anxiety Treatment Professional CCATP)",
            "evergreen certifications C-DBT"
        ],
        "Sex Therapy & Relationship Counseling": [
            "board certified sex therapist",
            "sex therapy training institute",
            "certified clinical trauma professional (CCTP)"
        ],

        "National & International Associations": [
            "american psychological association",
            "national academy of neuropsychology",
            "national academy of sports medicine",
            "national association of school psychologists NCSP",
            "national board of certified counselors NCC",
            "national council of certified dementia practitioners CDP",
            "national counseling association certified professional coach",
            "national register of health service psychologists (member in good standing)",
            "national institute of the psychotherapies",
            "international association trauma professionals",
            "international centre for emotionally focused therapy",
            "international certification board of clinical hypnotherapy"
        ],
        "Local & State Boards": [
            "state of California",
            "state of Florida department of public health PY",
            "state of Florida SW",
            "florida certification board (MCAP)",
            "florida certificate board (FBC)",
            "florida international university masters in social work",
            "florida licensed psychologist PY",
            "florida state university Ph.D.",
            "florida supreme court certified family law mediator"
        ],

        "Higher Education & Research": [
            "florida atlantic university certified in healthy aging",
            "florida atlantic university elementary education",
            "florida atlantic university Ph.D.",
            "florida state university Ph.D.",
            "harvard graduate school of education Ed.M.",
            "loyola marymount university masters in special education",
            "new york university advanced clinical study",
            "university of vermont larner college of medicine end-of-life doula"
        ],
        "Psychotherapy & Counseling Certifications": [
            "smith college school for social work certificate in individual psychotherapy",
            "ringling college of art and design certificate in art and healing",
            "postgraduate center for mental health psychoanalyst"
        ],

        "Mind-Body Medicine & Wellness": [
            "center for mind-body medicine - mindfulness",
            "florida international university masters in social work"
        ],
        "Mediation & Conflict Resolution": [
            "certification in family mediation",
            "florida supreme court certified family law mediator",
            "florida certification board MCAP",
            "florida certificate board CPP"
        ],
        "Professional Supervision & Teaching": [
            "licensed clinical supervisor",
            "qualified supervisor (MFT MHC)",
            "florida supreme court certified family law mediator"
        ],

        "Art Therapy & Creative Therapies": [
            "american art therapy association (AATA)",
            "art therapy credentialing board ATR-BC"
        ],
        "Sexual Health & Relationship Therapy": [
            "board certified sex therapist",
            "sex therapy training institute"
        ],
        "Addiction & Family Therapy": [
            "adoption competency trained",
            "certified addiction professional",
            "brief strategic family therapy (evidence-based) national trainer"
        ],
    "Other": []
}

# %% [markdown]
# ### Region 🗾

# %%
#   -----------------  Texas  -----------------


state_city_groups = {
    "texas": {
    "Dallas–Fort Worth Metroplex": [
        "Dallas", "Fort Worth", "Arlington", "Plano", "Irving", "Garland", "Grand Prairie", "Denton", "Frisco",
        "McKinney", "Lewisville", "Carrollton", "Richardson", "Grapevine", "Euless", "Mesquite", "Flower Mound",
        "The Colony", "Allen", "Addison", "Coppell", "Bedford", "North Richland Hills", "Hurst", "Roanoke", "Keller",
        "Mansfield", "Wylie", "Cedar Hill", "Duncanville", "DeSoto", "Sachse", "Farmers Branch", "Colleyville",
        "Southlake", "Rockwall", "Lancaster", "Trophy Club", "Murphy", "Richland Hills", "Highland Village", "Heath",
        "Haslet", "Little Elm", "Prosper", "Fairview", "Princeton", "Anna", "Celina", "Royse City", "Cleburne",
        "Burleson", "Weatherford", "Azle", "Saginaw", "Haltom City", "Lake Worth", "Waxahachie"
    ],
    "Greater Houston Area": [
        "Houston", "The Woodlands", "Sugar Land", "Pasadena", "Pearland", "Baytown", "League City", "Missouri City",
        "Conroe", "Friendswood", "Alvin", "Rosenberg", "Cypress", "Tomball", "Humble", "Channelview", "La Porte",
        "Deer Park", "Seabrook", "Stafford", "Porter", "Kingwood", "Katy", "Atascocita", "Clear Lake Shores",
        "Bellaire", "Webster", "Spring", "Spring Branch", "Hockley", "Richmond", "Mont Belvieu", "Manvel", "Fresno",
        "Brookshire", "Simonton", "Dayton", "Liberty Hill", "La Marque", "Dickinson", "Santa Fe", "Angleton",
        "Texas City", "Galveston"
    ],
    "Austin Area": [
        "Austin", "Round Rock", "Cedar Park", "Georgetown", "Pflugerville", "Leander", "Buda", "Kyle", "Hutto",
        "Lakeway", "West Lake Hills", "Lago Vista", "Manor", "Bee Cave", "Dripping Springs", "Sunset Valley",
        "Rollingwood"
    ],
    "San Antonio Area": [
        "San Antonio", "Schertz", "Converse", "Live Oak", "Universal City", "Selma", "Alamo Heights", "Helotes",
        "Boerne", "Fair Oaks Ranch", "Cibolo", "Castroville", "Garden Ridge", "New Braunfels", "Seguin"
    ],
    "Rio Grande Valley (South Texas)": [
        "McAllen", "Brownsville", "Edinburg", "Mission", "Pharr", "Harlingen", "Weslaco", "San Juan",
        "Rio Grande City", "Mercedes", "Raymondville", "South Padre Island", "San Benito", "Port Isabel", "Donna",
        "Alamo"
    ],
    "West Texas": [
        "El Paso", "Midland", "Odessa", "Lubbock", "Abilene", "San Angelo", "Big Spring", "Pecos", "Monahans",
        "Levelland", "Fort Stockton"
    ],
    "Central Texas": [
        "Waco", "Temple", "Killeen", "College Station", "Bryan", "Belton", "Harker Heights", "Hewitt",
        "Copperas Cove", "Woodway", "Salado", "Gatesville", "Georgetown", "Taylor"
    ],
    "East Texas": [
        "Tyler", "Longview", "Nacogdoches", "Lufkin", "Kilgore", "Jacksonville", "Henderson", "Lindale", "Palestine",
        "Mount Pleasant", "Center", "Crockett", "Whitehouse", "Gilmer", "Pittsburg", "Athens"
    ],
    "Gulf Coast": [
        "Corpus Christi", "Port Lavaca", "Rockport", "Port Aransas", "Bay City", "Port Arthur", "Texas City",
        "Galveston", "Beaumont", "Lake Jackson", "Victoria", "Freeport", "Angleton"
    ]
    },


#   -----------------  California  -----------------

    "california": {
        "San Francisco Bay Area": [
				"San Francisco", "Oakland", "Alameda", "Palo Alto", "Fremont", "Cupertino", "Berkeley", "Albany", "Pleasant Hill", "Burlingame", "Los Altos"
		 ],
         "Sacramento Area": [
				"Sacramento", "Elk Grove", "Roseville", "Rancho Cordova", "Woodland", "Granite Bay", "North Highlands", "Auburn"
		 ],
         "Central Valley": [
				"Fresno", "Stockton", "Modesto", "Lemoore", "Chico", "Redding"
		 ],
         "Wine Country": [
				"Santa Rosa", "Petaluma"
		 ],
         "Sierra Nevada & Foothills": [
				"Nevada City", "Crestline"
		 ],
         "Los Angeles Area": [
				"Los Angeles", "Santa Monica", "Beverly Hills", "Sherman Oaks", "Studio City", "Culver City", "Burbank", "Panorama City", "Northridge", "Sylmar", "Granada Hills", "Van Nuys", "Canoga Park"
		 ],
         "Orange County": [
				"Irvine", "Costa Mesa", "Huntington Beach", "Fountain Valley", "Laguna Hills", "Laguna Beach", "Mission Viejo", "Tustin",
        "Placentia", "Orange", "Santa Ana", "Fullerton", "Garden Grove", "Newport Beach", "Laguna Niguel", "San Clemente",
        "San Juan Capistrano", "Anaheim", "La Puente"
		 ],
         "San Diego Area": [
				"San Diego", "La Jolla", "Encinitas", "Escondido", "Del Mar", "Carlsbad", "Oceanside", "Chula Vista", "Vista", "Solana Beach"
		 ],
         "Inland Empire": [
				"Riverside", "Rancho Cucamonga", "Fontana", "Perris", "Temecula", "Menifee", "Yorba Linda",
        "Redlands", "Jurupa Valley", "Montclair", "Lake Elsinore", "Corona"
		 ],
        "Central Coast": [
        "Arroyo Grande", "Goleta", "Grover Beach", "Paso Robles", "Salinas", "Aptos",
        "San Luis Obispo", "Santa Barbara", "Santa Cruz", "Capitola", "Pacific Grove"
    ],
    "North Bay": [
        "Napa", "Novato", "Mill Valley", "San Rafael", "Sausalito", "Kentfield",
        "Windsor", "San Pablo", "San Carlos", "San Mateo", "Orinda", "Richmond"
    ],
    "South Bay": [
        "San Jose", "Saratoga", "Menlo Park", "Mountain View", "Morgan Hill", "Los Gatos"
    ],
    "San Gabriel Valley": [
        "Pasadena", "Glendora", "Altadena", "Temple City", "Arcadia"
    ],
    "High Desert": [
        "Hesperia", "Yucca Valley"
    ],
    "Coastal LA/OC Suburbs": [
        "Redondo Beach", "Hermosa Beach", "Rancho Palos Verdes", "Rolling Hills Estates",
        "Long Beach", "Palos Verdes", "Pacific Palisades"
    ],
    "East Bay": [
        "Hayward", "Newark", "Walnut Creek", "Benicia", "Danville"
    ],
         "Ventura County": [
				"Thousand Oaks", "Westlake Village", "Moorpark", "Camarillo", "Oxnard"
    ]
    },


#   -----------------  Flordia  -----------------

############################### Florida City Groups ###############################

    "florida": {
    "South Florida": [
        "Aventura", "Boca Raton", "Boynton Beach", "Coconut Creek", "Cooper City",
        "Coral Gables", "Coral Springs", "Davie", "Deerfield Beach", "Fort Lauderdale",
        "Hallandale Beach", "Hialeah", "Hollywood", "Homestead", "Lauderdale by the Sea",
        "Lauderhill", "Miami", "Miami Beach", "Miami Gardens", "Miramar",
        "North Palm Beach", "Palmetto Bay", "Pembroke Pines", "Pinecrest", "Plantation",
        "Pompano Beach", "South Miami", "Sunrise", "Tamarac", "Weston"
    ],
    "Central Florida": [
        "Altamonte Springs", "Celebration", "Clermont", "Davenport", "Debary", "Groveland",
        "Lake Mary", "Lakeland", "Maitland", "Orlando", "Oviedo", "Poinciana",
        "Polk City", "Windermere", "Winter Garden", "Winter Haven", "Winter Park", "Winter Springs"
    ],
    "Southwest Florida": [
        "Bonita Springs", "Cape Coral", "Estero", "Fort Myers", "Naples",
        "North Port", "Port Charlotte", "Punta Gorda", "Venice"
    ],
    "Southeast Florida / Treasure Coast": [
        "Indialantic", "Indian Shores", "Jupiter", "Lake Worth", "Loxahatchee",
        "Melbourne", "Melbourne Beach", "Merritt Island", "Palm Beach",
        "Palm Beach Gardens", "Palm City", "Port Saint Lucie", "Stuart",
        "Vero Beach", "Wellington", "West Palm Beach"
    ],
    "Tampa Bay Area / Central West Florida": [
        "Apollo Beach", "Bradenton", "Brandon", "Clearwater", "Largo", "Land O Lakes",
        "Odessa", "Riverview", "Safety Harbor", "Saint Petersburg", "Sun City Center",
        "Tampa", "Tarpon Springs", "Zephyrhills", "Lakewood Ranch"
    ],
    "Northeast Florida": [
        "Fernandina Beach", "Fleming Island", "Jacksonville", "Jacksonville Beach",
        "Middleburg", "Neptune Beach", "Orange Park", "Ponte Vedra", "Saint Augustine"
    ],
    "Northwest Florida / Panhandle": [
        "Defuniak Springs", "Destin", "Milton", "Pensacola", "Santa Rosa Beach", "Tallahassee"
    ],
    "North Central Florida": [
        "Gainesville", "Lake City", "Ocala", "Palm Coast", "The Villages", "Wildwood"
    ],
    "Other": [
        "Crawfordville", "Marathon", "Placida"
    ]
},



#   -----------------  New York  -----------------

############################### New York City Groups ###############################

    "new-york": {
      "New York City": [
          "Bronx", "Brooklyn", "Manhattan", "New York", "Queens",
          "Staten Island", "Astoria", "Cambria Heights", "Forest Hills",
          "Jackson Heights", "Jamaica", "Ridgewood"
      ],
      "Long Island": [
          "Babylon", "Bethpage", "Commack", "East Hampton", "East Moriches",
          "Glen Cove", "Glen Head", "Greenlawn", "Hicksville", "Huntington",
          "Huntington Station", "Lake Grove", "Long Beach", "Lynbrook",
          "Manorville", "Massapequa", "Merrick", "Montauk", "Oceanside",
          "Port Jefferson Station", "Riverhead", "Rockville Centre",
          "Ronkonkoma", "Roslyn", "Smithtown", "Wantagh", "West Hempstead",
          "West Islip", "West Sayville", "Westhampton", "Woodbury"
      ],
      "Hudson Valley": [
          "Ardsley", "Briarcliff Manor", "Carmel", "Chappaqua", "Goshen",
          "Hartsdale", "Irvington", "Katonah", "Larchmont", "Mamaroneck",
          "Manhasset", "Mount Kisco", "New City", "New Rochelle",
          "Nyack", "Ossining", "Pearl River", "Pelham", "Pound Ridge",
          "Rye", "Rye Brook", "Sleepy Hollow", "Tarrytown", "Valhalla",
          "Valley Cottage", "White Plains", "Yonkers", "Yorktown Heights"
      ],
      "Capital Region": [
          "Albany", "Clifton Park", "Scotia", "Troy"
      ],
      "Western NY": [
          "Buffalo", "Derby", "Elma", "Hamburg", "Jamestown", "Olean",
          "West Seneca", "Williamsville"
      ],
      "Finger Lakes": [
          "Canandaigua", "Fairport", "Penfield", "Rochester", "Spencerport",
          "Webster"
      ],
      "Central NY": [
          "Fayetteville", "Fulton", "Manlius", "Syracuse"
      ],
      "Southern Tier": [
          "Elmira", "Ithaca"
      ],
      "North Country / Other Upstate": [
          "Alfred", "Brewerton", "Cuba", "Ferndale", "Little Falls",
          "Millerton", "Morrisonville", "New Paltz", "New Windsor",
          "Palmyra", "Stone Ridge", "Warrensburg", "Warwick", "Vestal"
      ],
      "Uncategorized / Edge Cases": [
          "Freeport",  # could be LI or miscategorized
          "New Hyde Park",  # technically LI
      ]
  },

    "Other": {
        "Unknown Region": []  # Add more regions if needed
    }
}

# %% [markdown]
# ## FUNCTION

# %%
plots_to_insert = {}
##################################

def plot_horizontalBar(column,title):

    plt.style.use("dark_background")
    plt.figure(figsize=(10, 7))


    ax = sns.barplot(
        y=column.index,
        x=column.values,
        palette="plasma"
    )

    for index, value in enumerate(column.values):
        ax.text(value + 0.5, index, str(value), color='white', fontsize=9, va='center')

    plt.title(title, fontsize=14, color='white')
    plt.xticks(color='white')
    plt.yticks(color='white')

#    plt.show()

    # Save figure and register for insertion
    sheet_name = title.replace("Distribution of ", "").replace(" ", "_")
    img_path = f"{sheet_name}.png"
    plt.tight_layout()
    plt.savefig(img_path)
    plots_to_insert[sheet_name] = img_path
    plt.close()



############################################################################################


def plot_count_distribution(df, column_name, title):


    df[column_name] = df[column_name].fillna(0).astype(int)
    df = df[df[column_name] > 0]  # Remove zero values
    value_counts = df[column_name].dropna().value_counts().sort_index()


    plt.style.use("dark_background")
    plt.figure(figsize=(11, 4))


    ax = sns.barplot(
        x=value_counts.index.astype(str),
        y=value_counts.values,
        palette="coolwarm"
    )


    for index, value in enumerate(value_counts.values):
        ax.text(index, value + 0.5, str(value), color='white', fontsize=10, ha='center')


    plt.xlabel(column_name, fontsize=12, color='white')
    plt.ylabel("Count", fontsize=12, color='white')
    plt.title(title, fontsize=14, color='white')
    plt.xticks(rotation=45, color='white')
    plt.yticks(color='white')


#    plt.show()

    # Save figure and register for insertion
    sheet_name = "Aggregated_Stats"
    img_path = f"{column_name.replace(' ', '_')}.png"
    plt.tight_layout()
    plt.savefig(img_path)

    if sheet_name not in plots_to_insert:
        plots_to_insert[sheet_name] = []
    plots_to_insert[sheet_name].append(img_path)

    plt.close()


############################################################################################


def plot_donut(data, title):
    plt.style.use("dark_background")
    plt.figure(figsize=(6, 4))
    labels = data.index
    sizes = data.values
    colors = sns.color_palette("pastel", len(labels))

    fig, ax = plt.subplots(figsize=(4, 4))
    wedges, texts, autotexts = ax.pie(
        sizes, labels=labels, startangle=90, pctdistance=0.85, colors=colors,
        autopct=lambda p: f'{int(round(p * sum(sizes) / 100))} ({p:.1f}%)',
        textprops={'fontsize': 10}
    )

    centre_circle = plt.Circle((0, 0), 0.70, fc='white')
    ax.add_artist(centre_circle)
    plt.title(title)
    plt.show()


############################################################################################


def clean_and_split_column(df, column, delimiter='|'):
    return df[column].dropna().str.split(delimiter).explode().str.strip()


############################################################################################


def create_mapped_df(item_list, group_dict, column_name):
    mapping = {item: category for category, items in group_dict.items() for item in items}
    return pd.DataFrame({
        column_name: item_list,
        "Category": item_list.map(mapping).fillna("Other")
    })

# %% [markdown]
# # Loop - For Dementia

# %%
for state in states:
    print(f"Currently selecting: {state}")
    selected_state = state

    state_files = {
        selected_state: {


            "input": f"/content/therapist_data_{selected_state}.csv",
            "output": f"Dementia_Analysis_{selected_state}.xlsx"
                    }
                }



    file_path = state_files[selected_state]["input"]
    final_file = state_files[selected_state]["output"]


    df=pd.read_csv(file_path,encoding='latin-1')


    state_abbrev = {
        "texas": "TX",
        "california": "CA",
        "florida": "FL",
        "new-york": "NY"
    }

    pd.set_option("display.max_columns", None)

    df.shape



###############################  DEMENTIA  ###############################


    conditions = ['dementia', 'autism', 'depression']
    for condition in conditions:
        df[condition.capitalize()] = (
            df['Expertise'].str.lower().str.contains(condition, na=False) |
            df['Top Specialties'].str.lower().str.contains(condition, na=False)
            )


    Dementia=df[df['Dementia']==True]

    Dementia=Dementia[['Name','Title', 'Credential', 'Availability', 'City', 'State', 'ZIP Code',
                      'Individual Sessions ($)', 'Couple Sessions ($)',
                      'Insurance', 'Top Specialties', 'Expertise', 'Types of Therapy',
                      'In Practice (years)', 'Membership', 'Certificate',
                      'Major/Degree', 'Graduation Year', 'I also speak', 'Dementia']]

    Dementia["Title"]=Dementia["Title"].str.lower()

    selected_abbrev = state_abbrev.get(selected_state)
    Dementia = Dementia[Dementia['State'] == selected_abbrev]
    Dementia = Dementia.replace('Not Found', np.nan)
    #Dementia.info()




###############################  ALL COLUMNS  ###############################

###############################  Language  ###############################
    phrases_to_remove = [
        "se habla espaã±ol", "conversational", "in spanish and urdu",
        "conducting sessions in",  "english", "some", "fluent", "proficiency",
        "sorry only", "i can read in", "use search feature on our website",
        "slowly", "little", "also", "my ", "very", "i speak", "intermediate", "i am",
        "learning", "gracious", "not conversational", "semi-", "&", "beginner", "working toward fluency",
        "working knowledge of the", "language", "minimal", ' and', ' is'
    ]
    pattern = '|'.join(map(re.escape, phrases_to_remove))


    #Dementia['I also speak'] = Dementia['I also speak'].str.replace(r"[()\-\[\]{}]", "", regex=True)
    Dementia['I also speak'] = Dementia['I also speak'].str.replace(f"{pattern}|\\b(\\w+)\\s*\\|\\s*\\1\\b", r'\1', regex=True)
    language_list = clean_and_split_column(Dementia, 'I also speak', delimiter=r'\||,|/|\(|\)|-|\.')

    language_counts = language_list[language_list != 'not found'].value_counts()
    plot_horizontalBar(language_counts, "Distribution of Languages")


    ############################### Title  ################################
    title_mapping = {title: category for category, titles in title_groups.items() for title in titles}
    Dementia['Title_Category'] = Dementia['Title'].map(title_mapping).fillna("Other")
    plot_horizontalBar(Dementia['Title_Category'].value_counts(), "Distribution of Titles")


    ############################### Credential  ###############################
    credential_list = clean_and_split_column(Dementia, 'Credential',',')
    credential_mapping_df = create_mapped_df(credential_list, credential_groups, "Credential")
    plot_horizontalBar(credential_mapping_df['Category'].value_counts(), "Distribution of Credential")


    ############################### Insurance  ###############################
    Dementia['Insurance'] = Dementia['Insurance'].replace(
        "allied benefit systems- aetna", "allied benefit systems | aetna"
    )

    insurance_list = clean_and_split_column(Dementia, 'Insurance')
    insurance_mapping_df = create_mapped_df(insurance_list, insurance_groups, "Insurance")
    plot_horizontalBar(insurance_mapping_df['Category'].value_counts(), "Distribution of Insurance")



    ############################### Availability  ################################
    plot_horizontalBar(Dementia['Availability'].value_counts(), "Distribution of Availability")


    ############################### Expertise  ################################

    expertise_list = clean_and_split_column(Dementia, 'Expertise')
    Expertise = create_mapped_df(expertise_list, expertise_groups, "Expertise")
    plot_horizontalBar(Expertise['Category'].value_counts(), "Distribution of Expertise")


    ############################### Top Specialties  ################################

    top_specialties_list = clean_and_split_column(Dementia, 'Top Specialties')
    Top_specialties = create_mapped_df(top_specialties_list, top_specialties_groups, "Top_specialties")
    plot_horizontalBar(Top_specialties['Category'].value_counts(), "Distribution of Top Specialties")



    ############################### Therapy Types  ################################

    therapy_types_list = clean_and_split_column(Dementia, 'Types of Therapy')
    therapy_types = create_mapped_df(therapy_types_list, therapy_types_groups, "therapy_types")
    plot_horizontalBar(therapy_types['Category'].value_counts(), "Distribution of Therapy Types")


    ############################### Certification  ################################

    certificate_list = clean_and_split_column(Dementia, 'Certificate','/').str.replace(r'[\d,]', '', regex=True)
    certificate_mapping_df = create_mapped_df(certificate_list, certificate_groups, "Certificate")
    certificate_mapping_df = certificate_mapping_df.replace(r'^\s*$', pd.NA, regex=True)  # Replace blanks with NaN
    certificate_mapping_df = certificate_mapping_df.dropna()  # Drop rows with any NaN
    certificate_mapping_df.value_counts().sort_index()
    plot_horizontalBar(certificate_mapping_df['Category'].value_counts(), "Distribution of Certifications")


    ############################### Region  ################################

    city_groups = state_city_groups.get(selected_state, state_city_groups["Other"])
    city_mapping_df = create_mapped_df(Dementia["City"], city_groups, "City")
    city_mapping_df.value_counts()
    plot_horizontalBar(city_mapping_df['Category'].value_counts(), "Distribution of Region")


    ############################### Session charges, Practise years  ################################

    cols_to_clean = ['Individual Sessions ($)', 'Couple Sessions ($)', 'In Practice (years)']

    Dementia[cols_to_clean] = (
        Dementia[cols_to_clean]
        .astype(str)
        .replace('Not Found', np.nan)
        .apply(lambda x: x.str.replace(r'[$ ]', '', regex=True) if x.dtype == "object" else x)
        .apply(pd.to_numeric, errors='coerce')
        .replace(0, np.nan)
    )


    aggregated_stats = Dementia[cols_to_clean].agg(
        ['mean', 'median', 'min', 'max', 'std', 'count', 'nunique', lambda x: x.isnull().sum()])

    aggregated_stats = aggregated_stats.applymap(lambda x: int(x) if not pd.isna(x) else x).T

    for col in cols_to_clean + ['Graduation Year']:
        plot_count_distribution(Dementia, col, f'{col} distribution')





    ############################### Excel file download  ################################

    with pd.ExcelWriter(final_file, engine='xlsxwriter') as writer:
        language_counts.to_frame("Count").sort_index().to_excel(writer, sheet_name='Languages')
        Dementia[['Title_Category', 'Title']].value_counts().to_frame("Count").sort_index().to_excel(writer, sheet_name='Titles')
        Dementia[['Availability']].value_counts().to_frame("Count").sort_index().to_excel(writer, sheet_name='Availability')
        credential_mapping_df[['Category','Credential']].value_counts().to_frame("Count").sort_index().to_excel(writer, sheet_name='Credential')
        insurance_mapping_df[['Category', 'Insurance']].value_counts().to_frame("Count").sort_index().to_excel(writer, sheet_name='Insurance')

        Expertise[['Category', 'Expertise']].value_counts().to_frame("Count").sort_index().to_excel(writer, sheet_name='Expertise')
        Top_specialties[['Category', 'Top_specialties']].value_counts().to_frame("Count").sort_index().to_excel(writer, sheet_name='Top_Specialties')
        therapy_types[['Category', 'therapy_types']].value_counts().to_frame("Count").sort_index().to_excel(writer, sheet_name='Therapy_Types')
        certificate_mapping_df[['Category', 'Certificate']].value_counts().to_frame("Count").sort_index().to_excel(writer, sheet_name='Certifications')
        city_mapping_df[['Category', 'City']].value_counts().to_frame("Count").sort_index().to_excel(writer, sheet_name='Region')
        aggregated_stats.to_excel(writer, sheet_name='Aggregated_Stats')
        Dementia.sort_values(by=['Name'], ascending=True).to_excel(writer, sheet_name='Full Data', index=False)

        # Insert plots
        for sheet_name, img_path in plots_to_insert.items():
            try:
                worksheet = writer.sheets.get(sheet_name)
                if worksheet:
                    worksheet.insert_image("E2", img_path)
            except Exception as e:
                print(f"Could not insert image into sheet {sheet_name}: {e}")


        workbook = writer.book
        worksheet = writer.sheets.get("Aggregated_Stats")

        if worksheet and "Aggregated_Stats" in plots_to_insert:
            row = 6
            for img_path in plots_to_insert["Aggregated_Stats"]:
                worksheet.insert_image(f'A{row}', img_path)
                row += 20


    files.download(final_file)
# Out:
# Currently selecting: texas
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-11-0a2f3d9d7dde> in <cell line: 0>()
#      82
#      83     language_counts = language_list[language_list != 'not found'].value_counts()
# ---> 84     plot_horizontalBar(language_counts, "Distribution of Languages")
#      85
#      86
#
# <ipython-input-10-b601fa31a9ea> in plot_horizontalBar(column, title)
#      27     img_path = f"{sheet_name}.png"
#      28     plt.tight_layout()
# ---> 29     plt.savefig(img_path)
#      30     plots_to_insert[sheet_name] = img_path
#      31     plt.close()
#
# /usr/local/lib/python3.11/dist-packages/matplotlib/pyplot.py in savefig(*args, **kwargs)
#    1241     # savefig default implementation has no return, so mypy is unhappy
#    1242     # presumably this is here because subclasses can return?
# ...

# %% [markdown]
# # Loop - For Dementia + Suicide

# %%
for state in states:
    print(f"Currently selecting: {state}")
    selected_state = state

    state_files = {
        selected_state: {


            "input": f"/content/therapist_data_{selected_state}.csv",
            "output": f"Suicidal_Analysis_{selected_state}.xlsx"
                    }
                }



    file_path = state_files[selected_state]["input"]
    final_file = state_files[selected_state]["output"]


    df=pd.read_csv(file_path,encoding='latin-1')


    state_abbrev = {
        "texas": "TX",
        "california": "CA",
        "florida": "FL",
        "new-york": "NY"
    }

    pd.set_option("display.max_columns", None)

    df.shape



###############################  DEMENTIA + SUICIDAL  ###############################


    conditions = ['dementia', 'autism', 'depression']
    for condition in conditions:
        df[condition.capitalize()] = (
            df['Expertise'].str.lower().str.contains(condition, na=False) |
            df['Top Specialties'].str.lower().str.contains(condition, na=False)
            )


    Dementia=df[df['Dementia']==True]

    Dementia=Dementia[['Name','Title', 'Credential', 'Availability', 'City', 'State', 'ZIP Code',
                      'Individual Sessions ($)', 'Couple Sessions ($)',
                      'Insurance', 'Top Specialties', 'Expertise', 'Types of Therapy',
                      'In Practice (years)', 'Membership', 'Certificate',
                      'Major/Degree', 'Graduation Year', 'I also speak', 'Dementia']]



    Dementia["Title"]=Dementia["Title"].str.lower()

    selected_abbrev = state_abbrev.get(selected_state)
    Dementia = Dementia[Dementia['State'] == selected_abbrev]
    Dementia = Dementia.replace('Not Found', np.nan)
    #Dementia.info()


    suicidal_keywords = ['suicidal ideation', 'suicide prevention']
    Dementia['Suicidal Tendency'] = Dementia['Expertise'].str.lower().str.contains('|'.join(suicidal_keywords), na=False) | \
                                  Dementia['Top Specialties'].str.lower().str.contains('|'.join(suicidal_keywords), na=False)
    Suicidal=Dementia[Dementia['Suicidal Tendency']==True]

###############################  ALL COLUMNS  ###############################

###############################  Language  ###############################
    phrases_to_remove = [
        "se habla espaã±ol", "conversational", "in spanish and urdu",
        "conducting sessions in",  "english", "some", "fluent", "proficiency",
        "sorry only", "i can read in", "use search feature on our website",
        "slowly", "little", "also", "my ", "very", "i speak", "intermediate", "i am",
        "learning", "gracious", "not conversational", "semi-", "&", "beginner", "working toward fluency",
        "working knowledge of the", "language", "minimal", ' and', ' is'
    ]
    pattern = '|'.join(map(re.escape, phrases_to_remove))


    #Suicidal['I also speak'] = Suicidal['I also speak'].str.replace(r"[()\-\[\]{}]", "", regex=True)
    Suicidal['I also speak'] = Suicidal['I also speak'].str.replace(f"{pattern}|\\b(\\w+)\\s*\\|\\s*\\1\\b", r'\1', regex=True)
    language_list = clean_and_split_column(Suicidal, 'I also speak', delimiter=r'\||,|/|\(|\)|-|\.')

    language_counts = language_list[language_list != 'not found'].value_counts()
    plot_horizontalBar(language_counts, "Distribution of Languages")


    ############################### Title  ################################
    title_mapping = {title: category for category, titles in title_groups.items() for title in titles}
    Suicidal['Title_Category'] = Suicidal['Title'].map(title_mapping).fillna("Other")
    plot_horizontalBar(Suicidal['Title_Category'].value_counts(), "Distribution of Titles")


    ############################### Credential  ###############################
    credential_list = clean_and_split_column(Suicidal, 'Credential',',')
    credential_mapping_df = create_mapped_df(credential_list, credential_groups, "Credential")
    plot_horizontalBar(credential_mapping_df['Category'].value_counts(), "Distribution of Credential")


    ############################### Insurance  ###############################
    Suicidal['Insurance'] = Suicidal['Insurance'].replace(
        "allied benefit systems- aetna", "allied benefit systems | aetna"
    )

    insurance_list = clean_and_split_column(Suicidal, 'Insurance')
    insurance_mapping_df = create_mapped_df(insurance_list, insurance_groups, "Insurance")
    plot_horizontalBar(insurance_mapping_df['Category'].value_counts(), "Distribution of Insurance")



    ############################### Availability  ################################
    plot_horizontalBar(Suicidal['Availability'].value_counts(), "Distribution of Availability")


    ############################### Expertise  ################################

    expertise_list = clean_and_split_column(Suicidal, 'Expertise')
    Expertise = create_mapped_df(expertise_list, expertise_groups, "Expertise")
    plot_horizontalBar(Expertise['Category'].value_counts(), "Distribution of Expertise")


    ############################### Top Specialties  ################################

    top_specialties_list = clean_and_split_column(Suicidal, 'Top Specialties')
    Top_specialties = create_mapped_df(top_specialties_list, top_specialties_groups, "Top_specialties")
    plot_horizontalBar(Top_specialties['Category'].value_counts(), "Distribution of Top Specialties")



    ############################### Therapy Types  ################################

    therapy_types_list = clean_and_split_column(Suicidal, 'Types of Therapy')
    therapy_types = create_mapped_df(therapy_types_list, therapy_types_groups, "therapy_types")
    plot_horizontalBar(therapy_types['Category'].value_counts(), "Distribution of Therapy Types")


    ############################### Certification  ################################

    certificate_list = clean_and_split_column(Suicidal, 'Certificate','/').str.replace(r'[\d,]', '', regex=True)
    certificate_mapping_df = create_mapped_df(certificate_list, certificate_groups, "Certificate")
    certificate_mapping_df = certificate_mapping_df.replace(r'^\s*$', pd.NA, regex=True)  # Replace blanks with NaN
    certificate_mapping_df = certificate_mapping_df.dropna()  # Drop rows with any NaN
    certificate_mapping_df.value_counts().sort_index()
    plot_horizontalBar(certificate_mapping_df['Category'].value_counts(), "Distribution of Certifications")


    ############################### Region  ################################

    city_groups = state_city_groups.get(selected_state, state_city_groups["Other"])
    city_mapping_df = create_mapped_df(Suicidal["City"], city_groups, "City")
    city_mapping_df.value_counts()
    plot_horizontalBar(city_mapping_df['Category'].value_counts(), "Distribution of Region")


    ############################### Session charges, Practise years  ################################

    cols_to_clean = ['Individual Sessions ($)', 'Couple Sessions ($)', 'In Practice (years)']

    Suicidal[cols_to_clean] = (
        Suicidal[cols_to_clean]
        .astype(str)
        .replace('Not Found', np.nan)
        .apply(lambda x: x.str.replace(r'[$ ]', '', regex=True) if x.dtype == "object" else x)
        .apply(pd.to_numeric, errors='coerce')
        .replace(0, np.nan)
    )


    aggregated_stats = Suicidal[cols_to_clean].agg(
        ['mean', 'median', 'min', 'max', 'std', 'count', 'nunique', lambda x: x.isnull().sum()])

    aggregated_stats = aggregated_stats.applymap(lambda x: int(x) if not pd.isna(x) else x).T

    for col in cols_to_clean + ['Graduation Year']:
        plot_count_distribution(Suicidal, col, f'{col} distribution')





    ############################### Excel file download  ################################

    with pd.ExcelWriter(final_file, engine='xlsxwriter') as writer:
        language_counts.to_frame("Count").sort_index().to_excel(writer, sheet_name='Languages')
        Suicidal[['Title_Category', 'Title']].value_counts().to_frame("Count").sort_index().to_excel(writer, sheet_name='Titles')
        Suicidal[['Availability']].value_counts().to_frame("Count").sort_index().to_excel(writer, sheet_name='Availability')
        credential_mapping_df[['Category','Credential']].value_counts().to_frame("Count").sort_index().to_excel(writer, sheet_name='Credential')
        insurance_mapping_df[['Category', 'Insurance']].value_counts().to_frame("Count").sort_index().to_excel(writer, sheet_name='Insurance')

        Expertise[['Category', 'Expertise']].value_counts().to_frame("Count").sort_index().to_excel(writer, sheet_name='Expertise')
        Top_specialties[['Category', 'Top_specialties']].value_counts().to_frame("Count").sort_index().to_excel(writer, sheet_name='Top_Specialties')
        therapy_types[['Category', 'therapy_types']].value_counts().to_frame("Count").sort_index().to_excel(writer, sheet_name='Therapy_Types')
        certificate_mapping_df[['Category', 'Certificate']].value_counts().to_frame("Count").sort_index().to_excel(writer, sheet_name='Certifications')
        city_mapping_df[['Category', 'City']].value_counts().to_frame("Count").sort_index().to_excel(writer, sheet_name='Region')
        aggregated_stats.to_excel(writer, sheet_name='Aggregated_Stats')
        Suicidal.sort_values(by=['Name'], ascending=True).to_excel(writer, sheet_name='Suicidal+Dementia Data', index=False)
        Dementia.sort_values(by=['Name'], ascending=True).to_excel(writer, sheet_name='Full Data', index=False)

        # Insert plots
        for sheet_name, img_path in plots_to_insert.items():
            try:
                worksheet = writer.sheets.get(sheet_name)
                if worksheet:
                    worksheet.insert_image("E2", img_path)
            except Exception as e:
                print(f"Could not insert image into sheet {sheet_name}: {e}")


        workbook = writer.book
        worksheet = writer.sheets.get("Aggregated_Stats")

        if worksheet and "Aggregated_Stats" in plots_to_insert:
            row = 6
            for img_path in plots_to_insert["Aggregated_Stats"]:
                worksheet.insert_image(f'A{row}', img_path)
                row += 20


    files.download(final_file)
# Out:
# Currently selecting: texas
# Could not insert image into sheet Aggregated_Stats: Source must be a filename (str) or a BytesIO object.
# Currently selecting: california
# Could not insert image into sheet Aggregated_Stats: Source must be a filename (str) or a BytesIO object.
# Currently selecting: florida
# Could not insert image into sheet Aggregated_Stats: Source must be a filename (str) or a BytesIO object.
# Currently selecting: new-york
# Could not insert image into sheet Aggregated_Stats: Source must be a filename (str) or a BytesIO object.
